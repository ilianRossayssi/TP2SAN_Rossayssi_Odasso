# %%
import numpy as np
import msicpe.san as san
from plotly import express as px
import scipy.signal as signal

signal_dict = np.load('data_partie_1\ecg_signal.npz') # signal_dict est un dictionnaire contenant les données contenues dans le fichier signal.npz
s = signal_dict['s'] # extraction du signal utile
t = signal_dict['t'] # extraction du vecteur temps associé au signal

px.line(x = t, y = s, title="Signal temporel").show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# <>:6: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\mathi\AppData\Local\Temp\ipykernel_16892\2736436083.py:6: SyntaxWarning: invalid escape sequence '\e'
#   signal_dict = np.load('data_partie_1\ecg_signal.npz') # signal_dict est un dictionnaire contenant les données contenues dans le fichier signal.npz
